# %% [markdown]
# <a href="https://colab.research.google.com/github/kursatkara/MAE_5020_S24/blob/master/02_1_Eigenvalues_and_Eigenvectors_of_a_Matrix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Eigenvalues and Eigenvectors**
# by\
# Kursat Kara, ChatGPT4 and Codey
#
# Find the eigenvalues and eigenvectors of a matrix and plot the eigenvectors.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Define a matrix
A = np.array(
    [[1, 2],
     [3, 4]])
print("Matrix A :", A)

# Step 2: Find the eigenvalues and eigenvectors
eigenvalues, eigenvectors = np.linalg.eig(A)

# Step 3: Plot the eigenvectors
origin = [0, 0]

fig, ax = plt.subplots()
ax.quiver(*origin, *eigenvectors[:,0], angles='xy', scale_units='xy', scale=1, color='r', label='Eigenvector 1')
ax.quiver(*origin, *eigenvectors[:,1], angles='xy', scale_units='xy', scale=1, color='b', label='Eigenvector 2')

ax.set_xlim(-1, 1)
ax.set_ylim(-1, 1)
ax.set_aspect('equal')
ax.legend()

plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.title('Eigenvectors of the Positive Definite Orthogonal Matrix')
plt.show()

print("Eigenvalues:", eigenvalues)
print("Eigenvectors:", eigenvectors)
# Out:
# Matrix A : [[1 2]
#  [3 4]]
# Eigenvalues: [-0.37228132  5.37228132]
# Eigenvectors: [[-0.82456484 -0.41597356]
#  [ 0.56576746 -0.90937671]]

# %%
eigenvectors
# Out:
# array([[-0.82456484, -0.41597356],
#        [ 0.56576746, -0.90937671]])

# %%
ev1 = eigenvectors[:,0]
ev1
# Out:
# array([-0.82456484,  0.56576746])

# %%
ev2 = eigenvectors[:,1]
ev2
# Out:
# array([-0.41597356, -0.90937671])

# %%
dot_product_of_eigenvectors = np.dot(ev1,ev2)
dot_product_of_eigenvectors
# Out:
# -0.17149858514250893

# %% [markdown]
# Since the two vectors' dot product is not zero, the eigenvectors are not orthogonal.
